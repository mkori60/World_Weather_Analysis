# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | okha
# Processing Record 4 of Set 1 | katangli
# Processing Record 5 of Set 1 | luderitz
# Processing Record 6 of Set 1 | pemangkat
# Processing Record 7 of Set 1 | huaiyin
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | vyshestebliyevskaya
# Processing Record 11 of Set 1 | ponta delgada
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | bereda
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | chifeng
# Processing Record 17 of Set 1 | saint-pierre
# Processing Record 18 of Set 1 | kijang
# Processing Record 19 of Set 1 | znamenskoye
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | wilmington
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | ewa beach
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | berlevag
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | port hardy
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 37 of Set 1 | palatka
# Processing Record 38 of Set 1 | rivera
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | springdale
# Processing Record 41 of Set 1 | flin flon
# Processing Record 42 of Set 1 | padang
# Processing Record 43 of Set 1 | albacete
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | rawson
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | hun
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | garowe
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | palmer
# Processing Record 6 of Set 2 | san rafael del sur
# Processing Record 7 of Set 2 | mishan
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | geri
# Processing Record 10 of Set 2 | nouadhibou
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | miri
# Processing Record 13 of Set 2 | arawa
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | nome
# Processing Record 20 of Set 2 | aquiraz
# Processing Record 21 of Set 2 | porto novo
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | taoudenni
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | north battleford
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | chara
# Processing Record 29 of Set 2 | maceio
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | dongsheng
# Processing Record 33 of Set 2 | ulcinj
# Processing Record 34 of Set 2 | oistins
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | melilla
# Processing Record 37 of Set 2 | yining
# Processing Record 38 of Set 2 | paciran
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | mirnyy
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | olafsvik
# Processing Record 44 of Set 2 | mercedes
# Processing Record 45 of Set 2 | cayenne
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | beidao
# Processing Record 48 of Set 2 | sistranda
# Processing Record 49 of Set 2 | chokurdakh
# Processing Record 50 of Set 2 | pospelikha
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | rocha
# Processing Record 4 of Set 3 | ust-uda
# Processing Record 5 of Set 3 | sola
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | guthrie
# Processing Record 9 of Set 3 | shakawe
# Processing Record 10 of Set 3 | batagay-alyta
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | dondo
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | fairbanks
# Processing Record 15 of Set 3 | raigarh
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | kavieng
# Processing Record 18 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 3 | mogadishu
# Processing Record 20 of Set 3 | verkhneuralsk
# Processing Record 21 of Set 3 | bolshiye uki
# City not found. Skipping...
# Processing Record 22 of Set 3 | oyama
# Processing Record 23 of Set 3 | kang
# Processing Record 24 of Set 3 | beitbridge
# Processing Record 25 of Set 3 | bara
# Processing Record 26 of Set 3 | koygorodok
# Processing Record 27 of Set 3 | san marcos
# Processing Record 28 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 3 | vizimyary
# City not found. Skipping...
# Processing Record 30 of Set 3 | mizan teferi
# Processing Record 31 of Set 3 | uusikaupunki
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | vestmannaeyjar
# Processing Record 40 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 41 of Set 3 | hambantota
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | presidencia roque saenz pena
# Processing Record 44 of Set 3 | pilar
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | swift current
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | walvis bay
# Processing Record 49 of Set 3 | chervona sloboda
# Processing Record 50 of Set 3 | vite
# Processing Record 1 of Set 4 | ciudad bolivar
# Processing Record 2 of Set 4 | tahe
# Processing Record 3 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 4 of Set 4 | capaccio
# Processing Record 5 of Set 4 | oranjestad
# Processing Record 6 of Set 4 | pevek
# Processing Record 7 of Set 4 | sakaiminato
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | opuwo
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | port alfred
# Processing Record 13 of Set 4 | nuuk
# Processing Record 14 of Set 4 | surt
# Processing Record 15 of Set 4 | vaitape
# Processing Record 16 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | assiniboia
# Processing Record 19 of Set 4 | berdigestyakh
# Processing Record 20 of Set 4 | piranshahr
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | san antonio
# Processing Record 25 of Set 4 | baykit
# Processing Record 26 of Set 4 | tabuk
# Processing Record 27 of Set 4 | halifax
# Processing Record 28 of Set 4 | yilan
# Processing Record 29 of Set 4 | morgan city
# Processing Record 30 of Set 4 | yala
# Processing Record 31 of Set 4 | simplicio mendes
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | khani
# Processing Record 34 of Set 4 | mananara
# Processing Record 35 of Set 4 | letlhakeng
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | korla
# Processing Record 39 of Set 4 | okato
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | russell
# Processing Record 42 of Set 4 | vestmanna
# Processing Record 43 of Set 4 | great falls
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | guerrero negro
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | villa maria
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | harrisonburg
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | duvan
# Processing Record 3 of Set 5 | miranda
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | foz
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | muisne
# Processing Record 8 of Set 5 | akdepe
# Processing Record 9 of Set 5 | zhigansk
# Processing Record 10 of Set 5 | kimbe
# Processing Record 11 of Set 5 | acarau
# Processing Record 12 of Set 5 | olinda
# Processing Record 13 of Set 5 | toora-khem
# Processing Record 14 of Set 5 | whitehaven
# Processing Record 15 of Set 5 | adrar
# Processing Record 16 of Set 5 | fort abbas
# Processing Record 17 of Set 5 | voznesenye
# Processing Record 18 of Set 5 | osypenko
# Processing Record 19 of Set 5 | vilhena
# Processing Record 20 of Set 5 | sabirabad
# Processing Record 21 of Set 5 | north canton
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | torbay
# Processing Record 24 of Set 5 | seoni malwa
# Processing Record 25 of Set 5 | kribi
# Processing Record 26 of Set 5 | mao
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | registro
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | itoman
# Processing Record 31 of Set 5 | buenos aires
# Processing Record 32 of Set 5 | gusoeni
# Processing Record 33 of Set 5 | diffa
# Processing Record 34 of Set 5 | lhokseumawe
# Processing Record 35 of Set 5 | gurjaani
# Processing Record 36 of Set 5 | kaitangata
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | banda aceh
# Processing Record 42 of Set 5 | cap malheureux
# Processing Record 43 of Set 5 | tongzi
# Processing Record 44 of Set 5 | sladkovo
# Processing Record 45 of Set 5 | makat
# Processing Record 46 of Set 5 | houston
# Processing Record 47 of Set 5 | kondinskoye
# Processing Record 48 of Set 5 | chhatak
# Processing Record 49 of Set 5 | kiama
# Processing Record 50 of Set 5 | bathsheba
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | townsville
# Processing Record 3 of Set 6 | brooks
# Processing Record 4 of Set 6 | the valley
# Processing Record 5 of Set 6 | beyneu
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | ribeira grande
# Processing Record 8 of Set 6 | bac lieu
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | dukat
# Processing Record 11 of Set 6 | bantry
# Processing Record 12 of Set 6 | gallup
# Processing Record 13 of Set 6 | murdochville
# Processing Record 14 of Set 6 | redmond
# Processing Record 15 of Set 6 | makakilo city
# Processing Record 16 of Set 6 | port elizabeth
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | north platte
# Processing Record 20 of Set 6 | birao
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | kangaatsiaq
# Processing Record 23 of Set 6 | mount isa
# Processing Record 24 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 6 | itarema
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | marsa matruh
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | hovd
# Processing Record 31 of Set 6 | sandnessjoen
# Processing Record 32 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 33 of Set 6 | kaeng khlo
# City not found. Skipping...
# Processing Record 34 of Set 6 | gornopravdinsk
# Processing Record 35 of Set 6 | karaj
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | panji
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | jaen
# Processing Record 40 of Set 6 | ahipara
# Processing Record 41 of Set 6 | youghal
# Processing Record 42 of Set 6 | sosnovo-ozerskoye
# Processing Record 43 of Set 6 | dire dawa
# Processing Record 44 of Set 6 | kununurra
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | yar-sale
# Processing Record 47 of Set 6 | maracacume
# Processing Record 48 of Set 6 | segovia
# Processing Record 49 of Set 6 | sungaipenuh
# Processing Record 50 of Set 6 | mugla
# Processing Record 1 of Set 7 | dakar
# Processing Record 2 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 7 | kirkwall
# Processing Record 4 of Set 7 | ketchikan
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | kemijarvi
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | bilibino
# Processing Record 9 of Set 7 | sorland
# Processing Record 10 of Set 7 | vao
# Processing Record 11 of Set 7 | sanming
# Processing Record 12 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | novyy nekouz
# Processing Record 15 of Set 7 | crawfordsville
# Processing Record 16 of Set 7 | kampot
# Processing Record 17 of Set 7 | soligalich
# Processing Record 18 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 7 | trenggalek
# Processing Record 20 of Set 7 | kutum
# Processing Record 21 of Set 7 | omboue
# Processing Record 22 of Set 7 | uinskoye
# Processing Record 23 of Set 7 | krasnyy chikoy
# Processing Record 24 of Set 7 | kavaratti
# Processing Record 25 of Set 7 | kushva
# Processing Record 26 of Set 7 | tura
# Processing Record 27 of Set 7 | saquena
# Processing Record 28 of Set 7 | maldonado
# Processing Record 29 of Set 7 | aksu
# Processing Record 30 of Set 7 | hamilton
# Processing Record 31 of Set 7 | broome
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | zyryanka
# Processing Record 34 of Set 7 | westport
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | noumea
# Processing Record 37 of Set 7 | yazman
# Processing Record 38 of Set 7 | helena
# Processing Record 39 of Set 7 | panzhihua
# Processing Record 40 of Set 7 | denizli
# Processing Record 41 of Set 7 | betong
# Processing Record 42 of Set 7 | port blair
# Processing Record 43 of Set 7 | spassk-dalniy
# Processing Record 44 of Set 7 | xichang
# Processing Record 45 of Set 7 | san patricio
# Processing Record 46 of Set 7 | vyritsa
# Processing Record 47 of Set 7 | ancud
# Processing Record 48 of Set 7 | cape canaveral
# Processing Record 49 of Set 7 | codrington
# Processing Record 50 of Set 7 | la ronge
# Processing Record 1 of Set 8 | mareeba
# Processing Record 2 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 8 | teguise
# Processing Record 4 of Set 8 | mbandaka
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | pedernales
# Processing Record 7 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 8 | sumenep
# Processing Record 9 of Set 8 | alofi
# Processing Record 10 of Set 8 | mahanoro
# Processing Record 11 of Set 8 | mvuma
# Processing Record 12 of Set 8 | rincon
# Processing Record 13 of Set 8 | am timan
# Processing Record 14 of Set 8 | ouallam
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | hedensted
# Processing Record 17 of Set 8 | mildura
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | claremore
# Processing Record 20 of Set 8 | coquimbo
# Processing Record 21 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 8 | saint-gaudens
# Processing Record 23 of Set 8 | dabrowa gornicza
# Processing Record 24 of Set 8 | eenhana
# Processing Record 25 of Set 8 | malanje
# Processing Record 26 of Set 8 | shelburne
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | qiongshan
# Processing Record 29 of Set 8 | talcahuano
# Processing Record 30 of Set 8 | provideniya
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | mehamn
# Processing Record 33 of Set 8 | garissa
# Processing Record 34 of Set 8 | salinopolis
# Processing Record 35 of Set 8 | kaliua
# Processing Record 36 of Set 8 | luanda
# Processing Record 37 of Set 8 | malacatancito
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | te anau
# Processing Record 40 of Set 8 | rexburg
# Processing Record 41 of Set 8 | onufriyivka
# Processing Record 42 of Set 8 | chabahar
# Processing Record 43 of Set 8 | silvan
# Processing Record 44 of Set 8 | nuevo progreso
# Processing Record 45 of Set 8 | andenes
# Processing Record 46 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 8 | dosso
# Processing Record 48 of Set 8 | kamaishi
# Processing Record 49 of Set 8 | hauterive
# Processing Record 50 of Set 8 | nanortalik
# Processing Record 1 of Set 9 | kemi
# Processing Record 2 of Set 9 | vilnius
# Processing Record 3 of Set 9 | obera
# Processing Record 4 of Set 9 | maputo
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | izhma
# Processing Record 7 of Set 9 | mitu
# Processing Record 8 of Set 9 | pelym
# Processing Record 9 of Set 9 | trinidad
# Processing Record 10 of Set 9 | roxana
# Processing Record 11 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 9 | sidi ali
# Processing Record 13 of Set 9 | barabinsk
# Processing Record 14 of Set 9 | najran
# Processing Record 15 of Set 9 | saint-joseph
# Processing Record 16 of Set 9 | ebeltoft
# Processing Record 17 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | dalby
# Processing Record 19 of Set 9 | san cristobal
# Processing Record 20 of Set 9 | nantucket
# Processing Record 21 of Set 9 | sapernoye
# Processing Record 22 of Set 9 | kieta
# Processing Record 23 of Set 9 | oranjemund
# Processing Record 24 of Set 9 | odweyne
# Processing Record 25 of Set 9 | tyup
# Processing Record 26 of Set 9 | alexandria
# Processing Record 27 of Set 9 | apiai
# Processing Record 28 of Set 9 | teahupoo
# Processing Record 29 of Set 9 | zemio
# Processing Record 30 of Set 9 | imbituba
# Processing Record 31 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 9 | moose factory
# Processing Record 33 of Set 9 | cacule
# Processing Record 34 of Set 9 | salumbar
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | khandbari
# Processing Record 37 of Set 9 | kudahuvadhoo
# Processing Record 38 of Set 9 | pakwach
# City not found. Skipping...
# Processing Record 39 of Set 9 | komsomolskiy
# Processing Record 40 of Set 9 | paithan
# Processing Record 41 of Set 9 | stephenville crossing
# Processing Record 42 of Set 9 | santa rosa
# Processing Record 43 of Set 9 | bystryy istok
# Processing Record 44 of Set 9 | egvekinot
# Processing Record 45 of Set 9 | beatrice
# Processing Record 46 of Set 9 | yegros
# Processing Record 47 of Set 9 | yenagoa
# Processing Record 48 of Set 9 | raga
# Processing Record 49 of Set 9 | darayya
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | epiniana
# Processing Record 2 of Set 10 | port hedland
# Processing Record 3 of Set 10 | yarada
# Processing Record 4 of Set 10 | friesoythe
# Processing Record 5 of Set 10 | filadelfia
# Processing Record 6 of Set 10 | mahon
# Processing Record 7 of Set 10 | northampton
# Processing Record 8 of Set 10 | matay
# Processing Record 9 of Set 10 | solnechnyy
# Processing Record 10 of Set 10 | nelson bay
# Processing Record 11 of Set 10 | bambanglipuro
# Processing Record 12 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 10 | charters towers
# Processing Record 14 of Set 10 | kilindoni
# Processing Record 15 of Set 10 | flinders
# Processing Record 16 of Set 10 | nandu
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | mnogovershinnyy
# Processing Record 19 of Set 10 | hervey bay
# Processing Record 20 of Set 10 | louis trichardt
# Processing Record 21 of Set 10 | coihaique
# Processing Record 22 of Set 10 | northam
# Processing Record 23 of Set 10 | neuquen
# Processing Record 24 of Set 10 | bafia
# Processing Record 25 of Set 10 | blythe
# Processing Record 26 of Set 10 | balabac
# Processing Record 27 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 10 | bowen
# Processing Record 29 of Set 10 | wanning
# Processing Record 30 of Set 10 | dunedin
# Processing Record 31 of Set 10 | kifri
# Processing Record 32 of Set 10 | tasiilaq
# Processing Record 33 of Set 10 | mikhaylovka
# Processing Record 34 of Set 10 | kristinehamn
# Processing Record 35 of Set 10 | byron bay
# Processing Record 36 of Set 10 | elat
# Processing Record 37 of Set 10 | whitianga
# Processing Record 38 of Set 10 | sale
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | havelock
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | mazagao
# Processing Record 43 of Set 10 | lakes entrance
# Processing Record 44 of Set 10 | kasama
# Processing Record 45 of Set 10 | severnyy
# Processing Record 46 of Set 10 | khrebtovaya
# Processing Record 47 of Set 10 | bar harbor
# Processing Record 48 of Set 10 | richards bay
# Processing Record 49 of Set 10 | oksfjord
# Processing Record 50 of Set 10 | kushmurun
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 11 | sur
# Processing Record 5 of Set 11 | montepuez
# Processing Record 6 of Set 11 | craig
# Processing Record 7 of Set 11 | steamboat springs
# Processing Record 8 of Set 11 | mangrul pir
# Processing Record 9 of Set 11 | kerema
# Processing Record 10 of Set 11 | fort-shevchenko
# Processing Record 11 of Set 11 | nogales
# Processing Record 12 of Set 11 | lasa
# Processing Record 13 of Set 11 | caraquet
# Processing Record 14 of Set 11 | lyngseidet
# Processing Record 15 of Set 11 | rio grande
# Processing Record 16 of Set 11 | hosakote
# Processing Record 17 of Set 11 | nokha
# Processing Record 18 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 11 | chumikan
# Processing Record 20 of Set 11 | prince rupert
# Processing Record 21 of Set 11 | baft
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 11 | marsh harbour
# Processing Record 25 of Set 11 | atamanovka
# Processing Record 26 of Set 11 | caxito
# Processing Record 27 of Set 11 | golden
# Processing Record 28 of Set 11 | kattivakkam
# Processing Record 29 of Set 11 | summerville
# Processing Record 30 of Set 11 | yangjiang
# Processing Record 31 of Set 11 | emba
# Processing Record 32 of Set 11 | saiha
# Processing Record 33 of Set 11 | tiarei
# Processing Record 34 of Set 11 | limuru
# Processing Record 35 of Set 11 | owando
# Processing Record 36 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 11 | general cepeda
# Processing Record 38 of Set 11 | jiwani
# Processing Record 39 of Set 11 | dicabisagan
# Processing Record 40 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 11 | aklavik
# Processing Record 42 of Set 11 | anadyr
# Processing Record 43 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 11 | manzhouli
# Processing Record 45 of Set 11 | voh
# Processing Record 46 of Set 11 | creel
# Processing Record 47 of Set 11 | cuauhtemoc
# Processing Record 48 of Set 11 | ardmore
# Processing Record 49 of Set 11 | roches noires
# City not found. Skipping...
# Processing Record 50 of Set 11 | yenisehir
# Processing Record 1 of Set 12 | lebyazhye
# Processing Record 2 of Set 12 | kyzyl-suu
# Processing Record 3 of Set 12 | kargopol
# Processing Record 4 of Set 12 | ko samui
# Processing Record 5 of Set 12 | harper
# Processing Record 6 of Set 12 | lubango
# Processing Record 7 of Set 12 | rantepao
# Processing Record 8 of Set 12 | itaituba
# Processing Record 9 of Set 12 | grand gaube
# Processing Record 10 of Set 12 | cavalcante
# Processing Record 11 of Set 12 | zacualpan
# Processing Record 12 of Set 12 | tocaima
# Processing Record 13 of Set 12 | maragogi
# Processing Record 14 of Set 12 | gillette
# Processing Record 15 of Set 12 | kollo
# Processing Record 16 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 18 of Set 12 | myingyan
# Processing Record 19 of Set 12 | ugoofaaru
# Processing Record 20 of Set 12 | bemidji
# Processing Record 21 of Set 12 | taltal
# Processing Record 22 of Set 12 | havre-saint-pierre
# Processing Record 23 of Set 12 | sao joaquim
# Processing Record 24 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 12 | wencheng
# Processing Record 26 of Set 12 | benoy
# Processing Record 27 of Set 12 | almaznyy
# Processing Record 28 of Set 12 | chapleau
# Processing Record 29 of Set 12 | charagua
# Processing Record 30 of Set 12 | bafoulabe
# Processing Record 31 of Set 12 | ocampo
# Processing Record 32 of Set 12 | yuci
# Processing Record 33 of Set 12 | chardara
# Processing Record 34 of Set 12 | noyabrsk
# Processing Record 35 of Set 12 | camacupa
# Processing Record 36 of Set 12 | owosso
# Processing Record 37 of Set 12 | amapa
# Processing Record 38 of Set 12 | bahia blanca
# Processing Record 39 of Set 12 | shingu
# Processing Record 40 of Set 12 | port-cartier
# Processing Record 41 of Set 12 | muli
# Processing Record 42 of Set 12 | maun
# Processing Record 43 of Set 12 | laguna
# Processing Record 44 of Set 12 | golfito
# Processing Record 45 of Set 12 | smidovich
# Processing Record 46 of Set 12 | chapais
# Processing Record 47 of Set 12 | erice
# Processing Record 48 of Set 12 | fontem
# Processing Record 49 of Set 12 | sobolevo
# Processing Record 50 of Set 12 | monteagudo
# Processing Record 1 of Set 13 | svetlogorsk
# Processing Record 2 of Set 13 | asfi
# Processing Record 3 of Set 13 | kyshtovka
# Processing Record 4 of Set 13 | ostrovnoy
# Processing Record 5 of Set 13 | aktash
# Processing Record 6 of Set 13 | gat
# Processing Record 7 of Set 13 | linxia
# Processing Record 8 of Set 13 | ballina
# Processing Record 9 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 10 of Set 13 | wittingen
# Processing Record 11 of Set 13 | ribas do rio pardo
# Processing Record 12 of Set 13 | benxi
# Processing Record 13 of Set 13 | staryy nadym
# Processing Record 14 of Set 13 | le pont-de-claix
# Processing Record 15 of Set 13 | talavera de la reina
# Processing Record 16 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 13 | manali
# Processing Record 18 of Set 13 | banjar
# Processing Record 19 of Set 13 | gua musang
# Processing Record 20 of Set 13 | qasigiannguit
# Processing Record 21 of Set 13 | eyrarbakki
# Processing Record 22 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 23 of Set 13 | maradi
# Processing Record 24 of Set 13 | jambi
# Processing Record 25 of Set 13 | mashhad
# Processing Record 26 of Set 13 | waw
# Processing Record 27 of Set 13 | muros
# Processing Record 28 of Set 13 | zapolyarnyy
# Processing Record 29 of Set 13 | atotonilco el alto
# Processing Record 30 of Set 13 | goure
# Processing Record 31 of Set 13 | haines junction
# Processing Record 32 of Set 13 | constitucion
# Processing Record 33 of Set 13 | san quintin
# Processing Record 34 of Set 13 | emerald
# Processing Record 35 of Set 13 | gizo
# Processing Record 36 of Set 13 | shache
# Processing Record 37 of Set 13 | virginia beach
# Processing Record 38 of Set 13 | tagusao
# Processing Record 39 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | muscle shoals
# Processing Record 42 of Set 13 | launceston
# Processing Record 43 of Set 13 | karlskrona
# Processing Record 44 of Set 13 | neiafu
# Processing Record 45 of Set 13 | japura
# Processing Record 46 of Set 13 | camabatela
# Processing Record 47 of Set 13 | bicaz
# Processing Record 48 of Set 13 | margate
# Processing Record 49 of Set 13 | saint-paul
# Processing Record 50 of Set 13 | gimli
# Processing Record 1 of Set 14 | santa cruz
# Processing Record 2 of Set 14 | praia da vitoria
# Processing Record 3 of Set 14 | wajima
# Processing Record 4 of Set 14 | chute-aux-outardes
# Processing Record 5 of Set 14 | potsdam
# Processing Record 6 of Set 14 | tomatlan
# Processing Record 7 of Set 14 | sholokhovskiy
# Processing Record 8 of Set 14 | ilhabela
# Processing Record 9 of Set 14 | barentu
# Processing Record 10 of Set 14 | palana
# Processing Record 11 of Set 14 | ipira
# Processing Record 12 of Set 14 | sao joao da barra
# Processing Record 13 of Set 14 | montes altos
# Processing Record 14 of Set 14 | rongcheng
# Processing Record 15 of Set 14 | dongtai
# Processing Record 16 of Set 14 | stromness
# Processing Record 17 of Set 14 | svetlaya
# Processing Record 18 of Set 14 | vyartsilya
# Processing Record 19 of Set 14 | taos
# Processing Record 20 of Set 14 | maues
# Processing Record 21 of Set 14 | simbahan
# Processing Record 22 of Set 14 | ust-nera
# Processing Record 23 of Set 14 | altamirano
# Processing Record 24 of Set 14 | san francisco
# Processing Record 25 of Set 14 | tatawin
# Processing Record 26 of Set 14 | rundu
# Processing Record 27 of Set 14 | imperia
# Processing Record 28 of Set 14 | brae
# Processing Record 29 of Set 14 | sorong
# Processing Record 30 of Set 14 | bonavista
# Processing Record 31 of Set 14 | verkhnevilyuysk
# Processing Record 32 of Set 14 | teknaf
# Processing Record 33 of Set 14 | lapi
# Processing Record 34 of Set 14 | necochea
# Processing Record 35 of Set 14 | college
# Processing Record 36 of Set 14 | saint-francois
# Processing Record 37 of Set 14 | lisieux
# Processing Record 38 of Set 14 | karak
# Processing Record 39 of Set 14 | pingliang
# Processing Record 40 of Set 14 | kahului
# Processing Record 41 of Set 14 | mitsamiouli
# Processing Record 42 of Set 14 | monrovia
# Processing Record 43 of Set 14 | port augusta
# Processing Record 44 of Set 14 | pemba
# Processing Record 45 of Set 14 | altay
# Processing Record 46 of Set 14 | turochak
# Processing Record 47 of Set 14 | san andres
# Processing Record 48 of Set 14 | katsuura
# Processing Record 49 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 14 | buchanan
# Processing Record 1 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 15 | yumen
# Processing Record 3 of Set 15 | trairi
# Processing Record 4 of Set 15 | victor harbor
# Processing Record 5 of Set 15 | bud
# Processing Record 6 of Set 15 | gari
# Processing Record 7 of Set 15 | loukhi
# Processing Record 8 of Set 15 | zatoka
# Processing Record 9 of Set 15 | koslan
# Processing Record 10 of Set 15 | meulaboh
# Processing Record 11 of Set 15 | burns lake
# Processing Record 12 of Set 15 | nelidovo
# Processing Record 13 of Set 15 | numaligarh
# Processing Record 14 of Set 15 | humberto de campos
# Processing Record 15 of Set 15 | labuan
# Processing Record 16 of Set 15 | lukulu
# Processing Record 17 of Set 15 | ojinaga
# Processing Record 18 of Set 15 | scarborough
# Processing Record 19 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 15 | braganca
# Processing Record 21 of Set 15 | progreso
# Processing Record 22 of Set 15 | vallenar
# Processing Record 23 of Set 15 | cherskiy
# Processing Record 24 of Set 15 | qala
# Processing Record 25 of Set 15 | marrakesh
# Processing Record 26 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 15 | sarakhs
# Processing Record 28 of Set 15 | storforshei
# Processing Record 29 of Set 15 | eyl
# Processing Record 30 of Set 15 | mangrol
# Processing Record 31 of Set 15 | moron
# Processing Record 32 of Set 15 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 33 of Set 15 | hof
# Processing Record 34 of Set 15 | xifeng
# Processing Record 35 of Set 15 | borgo san dalmazzo
# Processing Record 36 of Set 15 | tucurui
# Processing Record 37 of Set 15 | prachuap khiri khan
# Processing Record 38 of Set 15 | kirkuk
# Processing Record 39 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 15 | barra do garcas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather_df = pd.DataFrame(city_data)

# %%
city_weather_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Albany  42.6001  -73.9662     75.02        34           1
# 1            Mahebourg -20.4081   57.7000     70.25        94          75
# 2                 Okha  53.5739  142.9478     43.16        93         100
# 3             Katangli  51.7102  143.2326     41.79        93          88
# 4             Luderitz -26.6481   15.1594     60.69        69           0
# 5            Pemangkat   1.1667  108.9667     76.80        84          96
# 6              Huaiyin  33.5886  119.0192     73.31        90          99
# 7               Kodiak  57.7900 -152.4072     47.71        93          90
# 8               Hobart -42.8794  147.3294     54.01        96          90
# 9  Vyshestebliyevskaya  45.1961   37.0181     64.81        79          18
#
#    Wind Speed Country Current Description
# 0        1.99      US           clear sky
# 1        9.22      MU          light rain
# 2       11.07      RU     overcast clouds
# 3        7.31      RU     overcast clouds
# 4       11.77      NA           clear sky
# 5        5.39      ID     overcast clouds
# 6        4.38      CN     overcast clouds
# 7       13.80      US          light rain
# 8        1.01      AU     overcast clouds
# 9       12.41      RU          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_weather_df = city_weather_df[new_column_order]

# %%
city_weather_df.head(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Albany      US  42.6001  -73.9662     75.02        34
# 1            Mahebourg      MU -20.4081   57.7000     70.25        94
# 2                 Okha      RU  53.5739  142.9478     43.16        93
# 3             Katangli      RU  51.7102  143.2326     41.79        93
# 4             Luderitz      NA -26.6481   15.1594     60.69        69
# 5            Pemangkat      ID   1.1667  108.9667     76.80        84
# 6              Huaiyin      CN  33.5886  119.0192     73.31        90
# 7               Kodiak      US  57.7900 -152.4072     47.71        93
# 8               Hobart      AU -42.8794  147.3294     54.01        96
# 9  Vyshestebliyevskaya      RU  45.1961   37.0181     64.81        79
#
#    Cloudiness  Wind Speed Current Description
# 0           1        1.99           clear sky
# 1          75        9.22          light rain
# 2         100       11.07     overcast clouds
# 3          88        7.31     overcast clouds
# 4           0       11.77           clear sky
# 5          96        5.39     overcast clouds
# 6          99        4.38     overcast clouds
# 7          90       13.80          light rain
# 8          90        1.01     overcast clouds
# 9          18       12.41          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
