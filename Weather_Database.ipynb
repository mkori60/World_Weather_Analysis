# %%
import pandas as pd 
import numpy as np 
import random 
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 1 | margate
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | dzhebariki-khaya
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | arenys de mar
# Processing Record 10 of Set 1 | sovetskiy
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | shakawe
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | kirakira
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | dunyapur
# Processing Record 20 of Set 1 | egvekinot
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | cairns
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 25 of Set 1 | dibulla
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | pedernales
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | saldanha
# Processing Record 33 of Set 1 | kampot
# Processing Record 34 of Set 1 | vigia del fuerte
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | olga
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | manacapuru
# Processing Record 41 of Set 1 | asau
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | zyryanka
# Processing Record 44 of Set 1 | venice
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | nizip
# Processing Record 49 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 1 | santa catarina de tepehuanes
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | dingle
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | poole
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | shimoda
# Processing Record 10 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | porto walter
# Processing Record 14 of Set 2 | coracora
# Processing Record 15 of Set 2 | lalmanir hat
# City not found. Skipping...
# Processing Record 16 of Set 2 | awbari
# Processing Record 17 of Set 2 | grindavik
# Processing Record 18 of Set 2 | gazalkent
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | katobu
# Processing Record 22 of Set 2 | monteagudo
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | nishihara
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | sur
# Processing Record 29 of Set 2 | malangwa
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | hofn
# Processing Record 32 of Set 2 | zonguldak
# Processing Record 33 of Set 2 | arboletes
# Processing Record 34 of Set 2 | nan
# Processing Record 35 of Set 2 | orlik
# Processing Record 36 of Set 2 | tambura
# Processing Record 37 of Set 2 | pyapon
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | whyalla
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | anloga
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | praia
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | waingapu
# Processing Record 1 of Set 3 | santa maria
# Processing Record 2 of Set 3 | kargasok
# Processing Record 3 of Set 3 | pampierstad
# Processing Record 4 of Set 3 | bambanglipuro
# Processing Record 5 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 3 | dhidhdhoo
# Processing Record 7 of Set 3 | phangnga
# Processing Record 8 of Set 3 | dalvik
# Processing Record 9 of Set 3 | the valley
# Processing Record 10 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | kaohsiung
# Processing Record 13 of Set 3 | minggang
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | wang saphung
# Processing Record 18 of Set 3 | verkhnevilyuysk
# Processing Record 19 of Set 3 | novikovo
# Processing Record 20 of Set 3 | umm lajj
# Processing Record 21 of Set 3 | flin flon
# Processing Record 22 of Set 3 | esperance
# Processing Record 23 of Set 3 | tura
# Processing Record 24 of Set 3 | aripuana
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | normandin
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | bonavista
# Processing Record 29 of Set 3 | cotonou
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | aquiraz
# Processing Record 32 of Set 3 | kharabali
# Processing Record 33 of Set 3 | bekhtery
# Processing Record 34 of Set 3 | maraa
# Processing Record 35 of Set 3 | jaora
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | aktau
# Processing Record 38 of Set 3 | bonthe
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | ayagoz
# Processing Record 42 of Set 3 | bogorodskoye
# Processing Record 43 of Set 3 | bilibino
# Processing Record 44 of Set 3 | nalut
# Processing Record 45 of Set 3 | nador
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | ushtobe
# Processing Record 49 of Set 3 | craigieburn
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | acapulco
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | gourcy
# Processing Record 5 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 4 | constantine
# Processing Record 7 of Set 4 | mitsamiouli
# Processing Record 8 of Set 4 | bama
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | esna
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | tual
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | san angelo
# Processing Record 16 of Set 4 | nuevo progreso
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | bintulu
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | paamiut
# Processing Record 22 of Set 4 | hualmay
# Processing Record 23 of Set 4 | tramandai
# Processing Record 24 of Set 4 | serenje
# Processing Record 25 of Set 4 | tuktoyaktuk
# Processing Record 26 of Set 4 | lorengau
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | faya
# Processing Record 29 of Set 4 | roma
# Processing Record 30 of Set 4 | takaka
# Processing Record 31 of Set 4 | aranos
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | lexington park
# Processing Record 34 of Set 4 | waddan
# Processing Record 35 of Set 4 | gigmoto
# Processing Record 36 of Set 4 | half moon bay
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | rabo de peixe
# Processing Record 40 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 4 | lasa
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | aguadilla
# Processing Record 44 of Set 4 | kabala
# Processing Record 45 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | daru
# Processing Record 48 of Set 4 | macusani
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | ayia galini
# Processing Record 1 of Set 5 | carballo
# Processing Record 2 of Set 5 | salinopolis
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | fukue
# Processing Record 5 of Set 5 | alta floresta
# Processing Record 6 of Set 5 | mogadishu
# Processing Record 7 of Set 5 | aswan
# Processing Record 8 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 5 | vanavara
# Processing Record 10 of Set 5 | la libertad
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | vila
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | bonoua
# Processing Record 15 of Set 5 | lastoursville
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | pierre
# Processing Record 18 of Set 5 | lagoa
# Processing Record 19 of Set 5 | diamantino
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | namibe
# Processing Record 22 of Set 5 | zhelyabovka
# Processing Record 23 of Set 5 | lang son
# Processing Record 24 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 5 | itoman
# Processing Record 26 of Set 5 | ust-kuyga
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | namtsy
# Processing Record 30 of Set 5 | butembo
# Processing Record 31 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | porto velho
# Processing Record 34 of Set 5 | san javier
# Processing Record 35 of Set 5 | tooele
# Processing Record 36 of Set 5 | tornio
# Processing Record 37 of Set 5 | uruzgan
# Processing Record 38 of Set 5 | barrow
# Processing Record 39 of Set 5 | sumalig
# Processing Record 40 of Set 5 | nelson bay
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | walvis bay
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | emmett
# Processing Record 45 of Set 5 | kieta
# Processing Record 46 of Set 5 | ponca city
# Processing Record 47 of Set 5 | padang
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | makarov
# Processing Record 1 of Set 6 | erzin
# Processing Record 2 of Set 6 | ribeira grande
# Processing Record 3 of Set 6 | mazamet
# Processing Record 4 of Set 6 | champerico
# Processing Record 5 of Set 6 | tubuala
# Processing Record 6 of Set 6 | innisfail
# Processing Record 7 of Set 6 | sandwick
# Processing Record 8 of Set 6 | nizhnyaya omka
# Processing Record 9 of Set 6 | macomb
# Processing Record 10 of Set 6 | wadi maliz
# Processing Record 11 of Set 6 | yellowknife
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | tandalti
# Processing Record 14 of Set 6 | sibolga
# Processing Record 15 of Set 6 | namatanai
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 6 | hovd
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | makakilo city
# Processing Record 24 of Set 6 | gat
# Processing Record 25 of Set 6 | erenhot
# Processing Record 26 of Set 6 | am timan
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | scarborough
# Processing Record 29 of Set 6 | nolinsk
# Processing Record 30 of Set 6 | lerwick
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | pinotepa nacional
# Processing Record 33 of Set 6 | praia da vitoria
# Processing Record 34 of Set 6 | rudbar
# Processing Record 35 of Set 6 | chekhov
# Processing Record 36 of Set 6 | dimbokro
# Processing Record 37 of Set 6 | itarema
# Processing Record 38 of Set 6 | leduc
# Processing Record 39 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | yarmouth
# Processing Record 41 of Set 6 | robertsport
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | antofagasta
# Processing Record 44 of Set 6 | bayan
# Processing Record 45 of Set 6 | quelimane
# Processing Record 46 of Set 6 | san quintin
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | barra do garcas
# Processing Record 49 of Set 6 | okhotsk
# Processing Record 50 of Set 6 | bogo
# Processing Record 1 of Set 7 | shenjiamen
# Processing Record 2 of Set 7 | porto novo
# Processing Record 3 of Set 7 | dawlatabad
# Processing Record 4 of Set 7 | ibra
# Processing Record 5 of Set 7 | bastia
# Processing Record 6 of Set 7 | lucapa
# Processing Record 7 of Set 7 | bollnas
# Processing Record 8 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | portage
# Processing Record 11 of Set 7 | wajima
# Processing Record 12 of Set 7 | rauma
# Processing Record 13 of Set 7 | skofja loka
# Processing Record 14 of Set 7 | foumban
# Processing Record 15 of Set 7 | hirara
# Processing Record 16 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 7 | ubatuba
# Processing Record 18 of Set 7 | riyadh
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | elk point
# Processing Record 21 of Set 7 | xinxiang
# Processing Record 22 of Set 7 | arklow
# Processing Record 23 of Set 7 | sioux lookout
# Processing Record 24 of Set 7 | pisco
# Processing Record 25 of Set 7 | zeya
# Processing Record 26 of Set 7 | boa vista
# Processing Record 27 of Set 7 | mount isa
# Processing Record 28 of Set 7 | zaozerne
# Processing Record 29 of Set 7 | dakar
# Processing Record 30 of Set 7 | naifaru
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | valleyview
# Processing Record 33 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 7 | abashiri
# Processing Record 35 of Set 7 | mikhaylov
# Processing Record 36 of Set 7 | abha
# Processing Record 37 of Set 7 | gerash
# Processing Record 38 of Set 7 | karratha
# Processing Record 39 of Set 7 | marawi
# Processing Record 40 of Set 7 | pangai
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | xinyu
# Processing Record 44 of Set 7 | merke
# Processing Record 45 of Set 7 | ratnagiri
# Processing Record 46 of Set 7 | san vicente
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | havre-saint-pierre
# Processing Record 49 of Set 7 | omsukchan
# Processing Record 50 of Set 7 | carbonia
# Processing Record 1 of Set 8 | kaeo
# Processing Record 2 of Set 8 | jining
# Processing Record 3 of Set 8 | kourou
# Processing Record 4 of Set 8 | sao jose da coroa grande
# Processing Record 5 of Set 8 | ostrovnoy
# Processing Record 6 of Set 8 | xining
# Processing Record 7 of Set 8 | amapa
# Processing Record 8 of Set 8 | kangaatsiaq
# Processing Record 9 of Set 8 | college
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | quballat
# Processing Record 12 of Set 8 | muros
# Processing Record 13 of Set 8 | timizart
# Processing Record 14 of Set 8 | koroni
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | kidal
# Processing Record 17 of Set 8 | rawson
# Processing Record 18 of Set 8 | laguna
# Processing Record 19 of Set 8 | salalah
# Processing Record 20 of Set 8 | caiaponia
# Processing Record 21 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 8 | jalu
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | puerto escondido
# Processing Record 25 of Set 8 | zaporizhzhya
# Processing Record 26 of Set 8 | camiri
# Processing Record 27 of Set 8 | pasighat
# Processing Record 28 of Set 8 | fort nelson
# Processing Record 29 of Set 8 | shingu
# Processing Record 30 of Set 8 | luwuk
# Processing Record 31 of Set 8 | trelew
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | vao
# Processing Record 36 of Set 8 | ouesso
# Processing Record 37 of Set 8 | syumsi
# Processing Record 38 of Set 8 | villazon
# Processing Record 39 of Set 8 | tanete
# Processing Record 40 of Set 8 | sabla
# Processing Record 41 of Set 8 | tsiroanomandidy
# Processing Record 42 of Set 8 | katherine
# Processing Record 43 of Set 8 | yershichi
# Processing Record 44 of Set 8 | santiago
# Processing Record 45 of Set 8 | north platte
# Processing Record 46 of Set 8 | sitka
# Processing Record 47 of Set 8 | qaqortoq
# Processing Record 48 of Set 8 | kaduna
# Processing Record 49 of Set 8 | la romana
# Processing Record 50 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 9 | skibbereen
# Processing Record 2 of Set 9 | inhambane
# Processing Record 3 of Set 9 | cabo san lucas
# Processing Record 4 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 5 of Set 9 | wahpeton
# Processing Record 6 of Set 9 | farim
# Processing Record 7 of Set 9 | urubicha
# Processing Record 8 of Set 9 | huarmey
# Processing Record 9 of Set 9 | eidfjord
# Processing Record 10 of Set 9 | majene
# Processing Record 11 of Set 9 | talaya
# Processing Record 12 of Set 9 | caravelas
# Processing Record 13 of Set 9 | ukwa
# Processing Record 14 of Set 9 | westport
# Processing Record 15 of Set 9 | bud
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | pozega
# Processing Record 18 of Set 9 | vicksburg
# Processing Record 19 of Set 9 | meilu
# City not found. Skipping...
# Processing Record 20 of Set 9 | bubaque
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | lanigan
# Processing Record 23 of Set 9 | ravar
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | taft
# Processing Record 26 of Set 9 | khour
# City not found. Skipping...
# Processing Record 27 of Set 9 | natal
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | labuhan
# Processing Record 30 of Set 9 | bin qirdan
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | port blair
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | kungurtug
# Processing Record 35 of Set 9 | vabalninkas
# Processing Record 36 of Set 9 | brae
# Processing Record 37 of Set 9 | joniskis
# Processing Record 38 of Set 9 | saint-augustin
# Processing Record 39 of Set 9 | pandan
# Processing Record 40 of Set 9 | torbay
# Processing Record 41 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 42 of Set 9 | sogamoso
# Processing Record 43 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 9 | balabac
# Processing Record 45 of Set 9 | hay river
# Processing Record 46 of Set 9 | george
# Processing Record 47 of Set 9 | kuopio
# Processing Record 48 of Set 9 | maturin
# Processing Record 49 of Set 9 | jadu
# Processing Record 50 of Set 9 | ust-nera
# Processing Record 1 of Set 10 | ancud
# Processing Record 2 of Set 10 | sibu
# Processing Record 3 of Set 10 | witu
# Processing Record 4 of Set 10 | marystown
# Processing Record 5 of Set 10 | buraydah
# Processing Record 6 of Set 10 | bowen
# Processing Record 7 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 10 | spirit river
# Processing Record 9 of Set 10 | severo-kurilsk
# Processing Record 10 of Set 10 | santa fe
# Processing Record 11 of Set 10 | klaksvik
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | neryungri
# Processing Record 14 of Set 10 | sobolevo
# Processing Record 15 of Set 10 | matara
# Processing Record 16 of Set 10 | pozzallo
# Processing Record 17 of Set 10 | jiuquan
# Processing Record 18 of Set 10 | semey
# Processing Record 19 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 10 | shihezi
# Processing Record 21 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 10 | surok
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | kachug
# Processing Record 25 of Set 10 | tutoia
# Processing Record 26 of Set 10 | kloulklubed
# Processing Record 27 of Set 10 | berlevag
# Processing Record 28 of Set 10 | chumikan
# Processing Record 29 of Set 10 | salitral
# Processing Record 30 of Set 10 | srandakan
# Processing Record 31 of Set 10 | kokstad
# Processing Record 32 of Set 10 | borogontsy
# Processing Record 33 of Set 10 | jiayuguan
# Processing Record 34 of Set 10 | shimonoseki
# Processing Record 35 of Set 10 | puerto del rosario
# Processing Record 36 of Set 10 | ko samui
# Processing Record 37 of Set 10 | east london
# Processing Record 38 of Set 10 | hays
# Processing Record 39 of Set 10 | hare bay
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | xichang
# Processing Record 42 of Set 10 | griffith
# Processing Record 43 of Set 10 | izhmorskiy
# Processing Record 44 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 10 | odweyne
# Processing Record 46 of Set 10 | jinchang
# Processing Record 47 of Set 10 | vila velha
# Processing Record 48 of Set 10 | baillif
# Processing Record 49 of Set 10 | tazovskiy
# Processing Record 50 of Set 10 | abu dhabi
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | chapais
# Processing Record 3 of Set 11 | kuala pilah
# Processing Record 4 of Set 11 | san jeronimo
# Processing Record 5 of Set 11 | tiarei
# Processing Record 6 of Set 11 | steinkjer
# Processing Record 7 of Set 11 | ishigaki
# Processing Record 8 of Set 11 | emerald
# Processing Record 9 of Set 11 | canete
# Processing Record 10 of Set 11 | lata
# Processing Record 11 of Set 11 | moroni
# Processing Record 12 of Set 11 | iskateley
# Processing Record 13 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 14 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 15 of Set 11 | mitu
# Processing Record 16 of Set 11 | palmerston
# Processing Record 17 of Set 11 | shache
# Processing Record 18 of Set 11 | kharan
# Processing Record 19 of Set 11 | shelburne
# Processing Record 20 of Set 11 | tchollire
# Processing Record 21 of Set 11 | kupang
# Processing Record 22 of Set 11 | porbandar
# Processing Record 23 of Set 11 | ajdabiya
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | marzuq
# Processing Record 26 of Set 11 | muisne
# Processing Record 27 of Set 11 | inirida
# Processing Record 28 of Set 11 | hearst
# Processing Record 29 of Set 11 | priladozhskiy
# Processing Record 30 of Set 11 | mao
# Processing Record 31 of Set 11 | wuda
# Processing Record 32 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 11 | crotone
# Processing Record 34 of Set 11 | maragogi
# Processing Record 35 of Set 11 | korla
# Processing Record 36 of Set 11 | mawlaik
# Processing Record 37 of Set 11 | athabasca
# Processing Record 38 of Set 11 | lethem
# Processing Record 39 of Set 11 | biak
# Processing Record 40 of Set 11 | rudsar
# Processing Record 41 of Set 11 | gwadar
# Processing Record 42 of Set 11 | puerto narino
# Processing Record 43 of Set 11 | komsomolskiy
# Processing Record 44 of Set 11 | pocatello
# Processing Record 45 of Set 11 | kavieng
# Processing Record 46 of Set 11 | port hardy
# Processing Record 47 of Set 11 | prata
# Processing Record 48 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 49 of Set 11 | pangody
# Processing Record 50 of Set 11 | terrak
# Processing Record 1 of Set 12 | adeje
# Processing Record 2 of Set 12 | tuy hoa
# Processing Record 3 of Set 12 | tomatlan
# Processing Record 4 of Set 12 | khash
# Processing Record 5 of Set 12 | mahon
# Processing Record 6 of Set 12 | nyaunglebin
# Processing Record 7 of Set 12 | oranjemund
# Processing Record 8 of Set 12 | hasaki
# Processing Record 9 of Set 12 | mecca
# Processing Record 10 of Set 12 | northam
# Processing Record 11 of Set 12 | gander
# Processing Record 12 of Set 12 | port-gentil
# Processing Record 13 of Set 12 | bridgend
# Processing Record 14 of Set 12 | sopo
# Processing Record 15 of Set 12 | kiama
# Processing Record 16 of Set 12 | saint-ambroise
# Processing Record 17 of Set 12 | lyuban
# Processing Record 18 of Set 12 | pajacuaran
# Processing Record 19 of Set 12 | mount holly
# Processing Record 20 of Set 12 | tari
# Processing Record 21 of Set 12 | flinders
# Processing Record 22 of Set 12 | lichtenau
# Processing Record 23 of Set 12 | voh
# Processing Record 24 of Set 12 | saint-pierre
# Processing Record 25 of Set 12 | inverell
# Processing Record 26 of Set 12 | burica
# City not found. Skipping...
# Processing Record 27 of Set 12 | san patricio
# Processing Record 28 of Set 12 | aksu
# Processing Record 29 of Set 12 | kamaishi
# Processing Record 30 of Set 12 | charters towers
# Processing Record 31 of Set 12 | carutapera
# Processing Record 32 of Set 12 | tianpeng
# Processing Record 33 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 12 | altay
# Processing Record 35 of Set 12 | neiafu
# Processing Record 36 of Set 12 | roald
# Processing Record 37 of Set 12 | mana
# Processing Record 38 of Set 12 | khasan
# Processing Record 39 of Set 12 | high level
# Processing Record 40 of Set 12 | yenagoa
# Processing Record 41 of Set 12 | winnipeg
# Processing Record 42 of Set 12 | tonekabon
# Processing Record 43 of Set 12 | ligaya
# Processing Record 44 of Set 12 | agadez
# Processing Record 45 of Set 12 | ust-ilimsk
# Processing Record 46 of Set 12 | yermakovskoye
# Processing Record 47 of Set 12 | turbat
# Processing Record 48 of Set 12 | lazaro cardenas
# Processing Record 49 of Set 12 | dawei
# Processing Record 50 of Set 12 | sarkand
# Processing Record 1 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 13 | corinto
# Processing Record 3 of Set 13 | mumford
# Processing Record 4 of Set 13 | okha
# Processing Record 5 of Set 13 | puerto asis
# Processing Record 6 of Set 13 | vestmanna
# Processing Record 7 of Set 13 | rosarito
# Processing Record 8 of Set 13 | tambacounda
# Processing Record 9 of Set 13 | sawtell
# Processing Record 10 of Set 13 | sao joao da ponte
# Processing Record 11 of Set 13 | wa
# City not found. Skipping...
# Processing Record 12 of Set 13 | beyneu
# Processing Record 13 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 13 | baghdad
# Processing Record 16 of Set 13 | izyum
# Processing Record 17 of Set 13 | guadalupe y calvo
# Processing Record 18 of Set 13 | cap-aux-meules
# Processing Record 19 of Set 13 | albemarle
# Processing Record 20 of Set 13 | kemijarvi
# Processing Record 21 of Set 13 | dwarka
# Processing Record 22 of Set 13 | dawson
# Processing Record 23 of Set 13 | talgar
# Processing Record 24 of Set 13 | singkang
# Processing Record 25 of Set 13 | zwedru
# Processing Record 26 of Set 13 | akyab
# Processing Record 27 of Set 13 | katsina
# Processing Record 28 of Set 13 | pilar
# Processing Record 29 of Set 13 | phek
# Processing Record 30 of Set 13 | ketchikan
# Processing Record 31 of Set 13 | alice springs
# Processing Record 32 of Set 13 | virginia beach
# Processing Record 33 of Set 13 | rio grande
# Processing Record 34 of Set 13 | waipawa
# Processing Record 35 of Set 13 | acolla
# Processing Record 36 of Set 13 | ahipara
# Processing Record 37 of Set 13 | mukhen
# Processing Record 38 of Set 13 | bathsheba
# Processing Record 39 of Set 13 | ambilobe
# Processing Record 40 of Set 13 | cabedelo
# Processing Record 41 of Set 13 | sambava
# Processing Record 42 of Set 13 | klyuchi
# Processing Record 43 of Set 13 | panaba
# Processing Record 44 of Set 13 | preobrazheniye
# Processing Record 45 of Set 13 | novyy urengoy
# Processing Record 46 of Set 13 | nicoya
# Processing Record 47 of Set 13 | kasempa
# Processing Record 48 of Set 13 | acacoyagua
# Processing Record 49 of Set 13 | staden
# Processing Record 50 of Set 13 | auki
# Processing Record 1 of Set 14 | coihaique
# Processing Record 2 of Set 14 | oriximina
# Processing Record 3 of Set 14 | birobidzhan
# Processing Record 4 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 14 | oranjestad
# Processing Record 6 of Set 14 | manjacaze
# Processing Record 7 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 14 | lavrentiya
# Processing Record 9 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 10 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 11 of Set 14 | emborion
# Processing Record 12 of Set 14 | saint-francois
# Processing Record 13 of Set 14 | raudeberg
# Processing Record 14 of Set 14 | mahibadhoo
# Processing Record 15 of Set 14 | zhezkazgan
# Processing Record 16 of Set 14 | llata
# Processing Record 17 of Set 14 | kutum
# Processing Record 18 of Set 14 | wicklow
# Processing Record 19 of Set 14 | kota kinabalu
# Processing Record 20 of Set 14 | karasjok
# Processing Record 21 of Set 14 | sosnowiec
# Processing Record 22 of Set 14 | umm kaddadah
# Processing Record 23 of Set 14 | vila do maio
# Processing Record 24 of Set 14 | sola
# Processing Record 25 of Set 14 | saint-louis
# Processing Record 26 of Set 14 | honningsvag
# Processing Record 27 of Set 14 | sungai besar
# Processing Record 28 of Set 14 | killybegs
# Processing Record 29 of Set 14 | dehloran
# Processing Record 30 of Set 14 | maltahohe
# Processing Record 31 of Set 14 | narsaq
# Processing Record 32 of Set 14 | monroe
# Processing Record 33 of Set 14 | greenwood
# Processing Record 34 of Set 14 | ailigandi
# Processing Record 35 of Set 14 | shubarshi
# Processing Record 36 of Set 14 | severo-yeniseyskiy
# Processing Record 37 of Set 14 | awjilah
# Processing Record 38 of Set 14 | ariquemes
# Processing Record 39 of Set 14 | compiegne
# Processing Record 40 of Set 14 | pochutla
# Processing Record 41 of Set 14 | pudozh
# Processing Record 42 of Set 14 | hulan ergi
# Processing Record 43 of Set 14 | rovinj
# Processing Record 44 of Set 14 | yumen
# Processing Record 45 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 14 | ye
# City not found. Skipping...
# Processing Record 47 of Set 14 | avera
# Processing Record 48 of Set 14 | havoysund
# Processing Record 49 of Set 14 | los llanos de aridane
# Processing Record 50 of Set 14 | moron
# Processing Record 1 of Set 15 | yeppoon
# Processing Record 2 of Set 15 | ola
# Processing Record 3 of Set 15 | hambantota
# Processing Record 4 of Set 15 | catabola
# Processing Record 5 of Set 15 | limon
# Processing Record 6 of Set 15 | we
# City not found. Skipping...
# Processing Record 7 of Set 15 | shiyan
# Processing Record 8 of Set 15 | thunder bay
# Processing Record 9 of Set 15 | tingi
# Processing Record 10 of Set 15 | xai-xai
# Processing Record 11 of Set 15 | puerto carreno
# Processing Record 12 of Set 15 | luderitz
# Processing Record 13 of Set 15 | vestmannaeyjar
# Processing Record 14 of Set 15 | mamallapuram
# Processing Record 15 of Set 15 | tanout
# Processing Record 16 of Set 15 | mugur-aksy
# Processing Record 17 of Set 15 | ulaangom
# Processing Record 18 of Set 15 | douglas
# Processing Record 19 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 15 | pankovka
# Processing Record 21 of Set 15 | kushima
# Processing Record 22 of Set 15 | ustka
# Processing Record 23 of Set 15 | kincardine
# Processing Record 24 of Set 15 | takhtamygda
# Processing Record 25 of Set 15 | santa helena
# Processing Record 26 of Set 15 | revin
# Processing Record 27 of Set 15 | leh
# Processing Record 28 of Set 15 | marang
# Processing Record 29 of Set 15 | azogues
# Processing Record 30 of Set 15 | jatai
# Processing Record 31 of Set 15 | rongcheng
# Processing Record 32 of Set 15 | maua
# Processing Record 33 of Set 15 | gamba
# Processing Record 34 of Set 15 | goba
# Processing Record 35 of Set 15 | lakatoro
# Processing Record 36 of Set 15 | russell
# Processing Record 37 of Set 15 | stuttgart
# Processing Record 38 of Set 15 | saraipali
# Processing Record 39 of Set 15 | aransas pass
# Processing Record 40 of Set 15 | kilindoni
# Processing Record 41 of Set 15 | neenah
# Processing Record 42 of Set 15 | binga
# Processing Record 43 of Set 15 | ngunguru
# Processing Record 44 of Set 15 | toyooka
# Processing Record 45 of Set 15 | pitimbu
# Processing Record 46 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 47 of Set 15 | rio claro
# Processing Record 48 of Set 15 | yumbe
# Processing Record 49 of Set 15 | yar-sale
# Processing Record 50 of Set 15 | mareeba
# Processing Record 1 of Set 16 | malartic
# Processing Record 2 of Set 16 | samarai
# Processing Record 3 of Set 16 | lulea
# Processing Record 4 of Set 16 | kiruna
# Processing Record 5 of Set 16 | okakarara
# Processing Record 6 of Set 16 | mungaoli
# Processing Record 7 of Set 16 | tyler
# Processing Record 8 of Set 16 | atikokan
# Processing Record 9 of Set 16 | zalantun
# Processing Record 10 of Set 16 | olonets
# Processing Record 11 of Set 16 | leshukonskoye
# Processing Record 12 of Set 16 | rafai
# Processing Record 13 of Set 16 | fairview
# Processing Record 14 of Set 16 | xudat
# Processing Record 15 of Set 16 | algete
# Processing Record 16 of Set 16 | asyut
# Processing Record 17 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 16 | marrakesh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Margate  51.3813    1.3862     63.30        90         100
# 1           Mataura -46.1927  168.8643     50.49        99         100
# 2      Punta Arenas -53.1500  -70.9167     28.51        86           0
# 3  Dzhebariki-Khaya  62.2167  135.8000     72.27        34          85
# 4           Ushuaia -54.8000  -68.3000     37.06        81          20
#
#    Wind Speed Country                 Date
# 0        5.99      GB  2021-06-15 03:30:51
# 1        1.50      NZ  2021-06-15 03:36:34
# 2        4.61      CL  2021-06-15 03:30:39
# 3        3.62      RU  2021-06-15 03:31:02
# 4       16.11      AR  2021-06-15 03:36:00

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
